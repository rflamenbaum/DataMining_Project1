# %%
import pandas as pd
import numpy as np
import datetime as dt
import os
from itertools import product
import pickle
import matplotlib.pyplot as plt
from matplotlib import cm
from sklearn.preprocessing import StandardScaler
# %matplotlib inline

import seaborn as sns
sns.set_style("whitegrid")

# %%
# df = pd.read_csv('C:\\Users\\RFlamenb\\OneDrive - Sempra Energy\\documents\\SMU\\Data_Mining_MSDS7331\\Project1_Master\\data\\Crime_SDCounty_5.csv')

# %%
# df.to_pickle('C:\\Users\\RFlamenb\\OneDrive - Sempra Energy\\documents\\SMU\\Data_Mining_MSDS7331\\Project1_NewAttempt\\data\\df.pkl')

# %%
dfp = pd.read_pickle('C:\\Users\\RFlamenb\\OneDrive - Sempra Energy\\documents\\SMU\\Data_Mining_MSDS7331\\Project1_NewAttempt\\data\\df.pkl')
dfp.head()
# Out:
#    TRACTCE10  BLOCKCE10  INTPTLAT10  INTPTLON10  POP100  HU100        date  \
# 0      16902       1186   32.929292 -116.857475      42     13  10/27/2010
# 1      16902       1186   32.929292 -116.857475      42     13   7/15/2011
# 2      16402       1040   32.810030 -116.910522     189     68   3/14/2008
# 3      16402       1040   32.810030 -116.910522     189     68   5/26/2008
# 4      16402       1040   32.810030 -116.910522     189     68   9/12/2008
#
#      year  month     day        ...          Jurisdiction_Population  \
# 0  2010.0   10.0  3952.0        ...                         485602.0
# 1  2011.0    7.0  4213.0        ...                         485602.0
# 2  2008.0    3.0  2995.0        ...                         485602.0
# 3  2008.0    5.0  3068.0        ...                         485602.0
# 4  2008.0    9.0  3177.0        ...                         485602.0
#
#    TWO_OR_MORE MdeAge_HISPANIC  MedAge_BLACK MedAge_ASIAN  MedAgeWHITE  \
# 0      13754.0            25.9          29.3         39.0         44.3
# 1      13754.0            25.9          29.3         39.0         44.3
# 2      13754.0            25.9          29.3         39.0         44.3
# 3      13754.0            25.9          29.3         39.0         44.3
# 4      13754.0            25.9          29.3         39.0         44.3
#
#   MedAge_AMERICAN_INDIAN MedAge_OTHER MedAge_PACIFIC_ISLANDER  \
# 0                   30.7         31.3                    29.1
# 1                   30.7         31.3                    29.1
# 2                   30.7         31.3                    29.1
# 3                   30.7         31.3                    29.1
# 4                   30.7         31.3                    29.1
#
#   MedAge_TWO_OR_MORE
# 0               19.8
# 1               19.8
# 2               19.8
# 3               19.8
# 4               19.8
#
# [5 rows x 52 columns]

# %%
dfp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 747213 entries, 0 to 747212
# Data columns (total 52 columns):
# TRACTCE10                   747213 non-null int64
# BLOCKCE10                   747213 non-null int64
# INTPTLAT10                  747213 non-null float64
# INTPTLON10                  747213 non-null float64
# POP100                      747213 non-null int64
# HU100                       747213 non-null int64
# date                        727534 non-null object
# year                        727534 non-null float64
# month                       727534 non-null float64
# day                         727534 non-null float64
# week                        727534 non-null float64
# dow                         727534 non-null float64
# time                        727534 non-null object
# hour                        727534 non-null float64
# address                     727534 non-null object
# is_night                    727534 non-null float64
# type                        727534 non-null object
# city                        727534 non-null object
# nbrhood                     727534 non-null object
# community                   727534 non-null object
# comm_pop                    727534 non-null float64
# asr_zone                    361945 non-null float64
# council                     727534 non-null object
# council_pop                 727534 non-null float64
# lampdist                    361945 non-null float64
# desc_                       727498 non-null object
# lat                         727534 non-null float64
# lon                         727534 non-null float64
# SHAPE_Area                  747213 non-null float64
# PovertyPercentage           727534 non-null float64
# Crime_Indicator             747213 non-null int64
# LawEnf_ID                   747213 non-null int64
# LawEnf_Facility_Distance    747213 non-null float64
# Jurisdiction                727534 non-null object
# HISPANIC                    727534 non-null float64
# Jurisdiction_1              727534 non-null object
# BLACK                       727534 non-null float64
# AMERICAN_INDIAN             727534 non-null float64
# WHITE                       727534 non-null float64
# ASIAN                       727534 non-null float64
# OTHER                       727534 non-null float64
# PACIFIC_ISLANDER            727534 non-null float64
# Jurisdiction_Population     727534 non-null float64
# TWO_OR_MORE                 727534 non-null float64
# MdeAge_HISPANIC             727534 non-null float64
# MedAge_BLACK                727534 non-null float64
# MedAge_ASIAN                727534 non-null float64
# MedAgeWHITE                 727534 non-null float64
# MedAge_AMERICAN_INDIAN      727534 non-null float64
# MedAge_OTHER                727534 non-null float64
# MedAge_PACIFIC_ISLANDER     727534 non-null float64
# MedAge_TWO_OR_MORE          727534 non-null float64
# dtypes: float64(35), int64(6), object(11)
# memory usage: 296.4+ MB

# %%
dups = dfp.duplicated(subset=None, keep='first').sum()

print('Duplicate Records:',dups)
# Out:
# Duplicate Records: 2354

# %%
dfp.isnull().sum()
# Out:
# TRACTCE10                        0
# BLOCKCE10                        0
# INTPTLAT10                       0
# INTPTLON10                       0
# POP100                           0
# HU100                            0
# date                         19679
# year                         19679
# month                        19679
# day                          19679
# week                         19679
# dow                          19679
# time                         19679
# hour                         19679
# address                      19679
# is_night                     19679
# type                         19679
# city                         19679
# nbrhood                      19679
# community                    19679
# comm_pop                     19679
# asr_zone                    385268
# council                      19679
# council_pop                  19679
# lampdist                    385268
# desc_                        19715
# lat                          19679
# lon                          19679
# SHAPE_Area                       0
# PovertyPercentage            19679
# Crime_Indicator                  0
# LawEnf_ID                        0
# LawEnf_Facility_Distance         0
# Jurisdiction                 19679
# HISPANIC                     19679
# Jurisdiction_1               19679
# BLACK                        19679
# AMERICAN_INDIAN              19679
# WHITE                        19679
# ASIAN                        19679
# OTHER                        19679
# PACIFIC_ISLANDER             19679
# Jurisdiction_Population      19679
# TWO_OR_MORE                  19679
# MdeAge_HISPANIC              19679
# MedAge_BLACK                 19679
# MedAge_ASIAN                 19679
# MedAgeWHITE                  19679
# MedAge_AMERICAN_INDIAN       19679
# MedAge_OTHER                 19679
# MedAge_PACIFIC_ISLANDER      19679
# MedAge_TWO_OR_MORE           19679
# dtype: int64

# %%
block_crimes = dfp.groupby(['BLOCKCE10','TRACTCE10','POP100','HU100','PovertyPercentage','LawEnf_Facility_Distance','HISPANIC',
          'BLACK','AMERICAN_INDIAN','WHITE','ASIAN','OTHER','PACIFIC_ISLANDER','Jurisdiction_Population',
           'TWO_OR_MORE','MdeAge_HISPANIC','MedAge_BLACK','MedAge_ASIAN','MedAgeWHITE','MedAge_AMERICAN_INDIAN',
           'MedAge_OTHER','MedAge_PACIFIC_ISLANDER','MedAge_TWO_OR_MORE']).size().reset_index(name='Count')
block_crimes.head()
# Out:
#    BLOCKCE10  TRACTCE10  POP100  HU100  PovertyPercentage  \
# 0       1000        100     312    180             0.1417
# 1       1000        201      30     16             0.1417
# 2       1000        202      60     38             0.1417
# 3       1000        300      28     21             0.1417
# 4       1000        400     834    531             0.1417
#
#    LawEnf_Facility_Distance  HISPANIC    BLACK  AMERICAN_INDIAN     WHITE  \
# 0               1087.307923  374977.0  81340.0           3469.0  586799.0
# 1               2056.835594  374977.0  81340.0           3469.0  586799.0
# 2               2344.236589  374977.0  81340.0           3469.0  586799.0
# 3               1602.084562  374977.0  81340.0           3469.0  586799.0
# 4                977.248455  374977.0  81340.0           3469.0  586799.0
#
#    ...    TWO_OR_MORE  MdeAge_HISPANIC  MedAge_BLACK  MedAge_ASIAN  \
# 0  ...        42603.0             27.4          33.7          34.4
# 1  ...        42603.0             27.4          33.7          34.4
# 2  ...        42603.0             27.4          33.7          34.4
# 3  ...        42603.0             27.4          33.7          34.4
# 4  ...        42603.0             27.4          33.7          34.4
#
#    MedAgeWHITE  MedAge_AMERICAN_INDIAN  MedAge_OTHER  MedAge_PACIFIC_ISLANDER  \
# 0         39.8                    33.9          28.2                     33.1
# 1         39.8                    33.9          28.2                     33.1
# 2         39.8                    33.9          28.2                     33.1
# 3         39.8                    33.9          28.2                     33.1
# 4         39.8                    33.9          28.2                     33.1
#
#    MedAge_TWO_OR_MORE  Count
# 0                21.9      9
# 1                21.9      3
# 2                21.9     12
# 3                21.9      9
# 4                21.9    263
#
# [5 rows x 24 columns]

# %%
block_crimes['HighCrimeArea'] = (block_crimes.Count/block_crimes.POP100) # this creates a new variable
block_crimes.tail()
# Out:
#        BLOCKCE10  TRACTCE10  POP100  HU100  PovertyPercentage  \
# 23814       7032       7600      23     13             0.1417
# 23815       7034       7600      11      7             0.1417
# 23816       7035       7600       5      4             0.1417
# 23817       7038       7600       3      7             0.1417
# 23818       7039       7600       2      6             0.1417
#
#        LawEnf_Facility_Distance  HISPANIC    BLACK  AMERICAN_INDIAN     WHITE  \
# 23814               2644.567527  374977.0  81340.0           3469.0  586799.0
# 23815               2746.165987  374977.0  81340.0           3469.0  586799.0
# 23816               2709.573382  374977.0  81340.0           3469.0  586799.0
# 23817               2761.682655  374977.0  81340.0           3469.0  586799.0
# 23818               2778.378502  374977.0  81340.0           3469.0  586799.0
#
#            ...        MdeAge_HISPANIC  MedAge_BLACK  MedAge_ASIAN  \
# 23814      ...                   27.4          33.7          34.4
# 23815      ...                   27.4          33.7          34.4
# 23816      ...                   27.4          33.7          34.4
# 23817      ...                   27.4          33.7          34.4
# 23818      ...                   27.4          33.7          34.4
#
#        MedAgeWHITE  MedAge_AMERICAN_INDIAN  MedAge_OTHER  \
# 23814         39.8                    33.9          28.2
# 23815         39.8                    33.9          28.2
# 23816         39.8                    33.9          28.2
# 23817         39.8                    33.9          28.2
# 23818         39.8                    33.9          28.2
#
#        MedAge_PACIFIC_ISLANDER  MedAge_TWO_OR_MORE  Count  HighCrimeArea
# 23814                     33.1                21.9      1       0.043478
# 23815                     33.1                21.9      7       0.636364
# 23816                     33.1                21.9      8       1.600000
# 23817                     33.1                21.9      9       3.000000
# 23818                     33.1                21.9     10       5.000000
#
# [5 rows x 25 columns]

# %%
crimePCT = block_crimes['Count']
crimePCT.dropna(inplace=True)
crimePCT.plot(kind='hist', range=[0, 50])

# %%
block_crimes['HighCrimeIDC'] = (block_crimes.HighCrimeArea > 0.25) # this creates a new variable
block_crimes.tail()
# Out:
#        BLOCKCE10  TRACTCE10  POP100  HU100  PovertyPercentage  \
# 23814       7032       7600      23     13             0.1417
# 23815       7034       7600      11      7             0.1417
# 23816       7035       7600       5      4             0.1417
# 23817       7038       7600       3      7             0.1417
# 23818       7039       7600       2      6             0.1417
#
#        LawEnf_Facility_Distance  HISPANIC    BLACK  AMERICAN_INDIAN     WHITE  \
# 23814               2644.567527  374977.0  81340.0           3469.0  586799.0
# 23815               2746.165987  374977.0  81340.0           3469.0  586799.0
# 23816               2709.573382  374977.0  81340.0           3469.0  586799.0
# 23817               2761.682655  374977.0  81340.0           3469.0  586799.0
# 23818               2778.378502  374977.0  81340.0           3469.0  586799.0
#
#            ...       MedAge_BLACK  MedAge_ASIAN  MedAgeWHITE  \
# 23814      ...               33.7          34.4         39.8
# 23815      ...               33.7          34.4         39.8
# 23816      ...               33.7          34.4         39.8
# 23817      ...               33.7          34.4         39.8
# 23818      ...               33.7          34.4         39.8
#
#        MedAge_AMERICAN_INDIAN  MedAge_OTHER  MedAge_PACIFIC_ISLANDER  \
# 23814                    33.9          28.2                     33.1
# 23815                    33.9          28.2                     33.1
# 23816                    33.9          28.2                     33.1
# 23817                    33.9          28.2                     33.1
# 23818                    33.9          28.2                     33.1
#
#        MedAge_TWO_OR_MORE  Count  HighCrimeArea  HighCrimeIDC
# 23814                21.9      1       0.043478         False
# 23815                21.9      7       0.636364          True
# 23816                21.9      8       1.600000          True
# 23817                21.9      9       3.000000          True
# 23818                21.9     10       5.000000          True
#
# [5 rows x 26 columns]

# %%
high_crime_var = block_crimes['HighCrimeIDC']
high_crime_var.plot(kind='hist')
